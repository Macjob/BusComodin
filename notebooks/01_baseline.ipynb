# %% [markdown]
# # BusComodin — M0 baseline
# Este notebook consume el mismo core de simulación que la CLI; no implementa lógica paralela.

# %%
from buscomodin.scenario import load_scenario
from buscomodin.simulation import run_baseline

scenario = load_scenario()
result = run_baseline(scenario, seed=42)
result.to_dict()
